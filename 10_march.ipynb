# %% [markdown]
# Q1: What is Estimation Statistics? Explain Point Estimate and Interval Estimate.
# Estimation Statistics involves using sample data to estimate the parameters of a population. There are two main types of estimates:
#
# Point Estimate: A single value that serves as an estimate of a population parameter.
#
# Interval Estimate: A range of values, derived from a sample, that is likely to contain the population parameter. It includes a margin of error and a confidence level. For example, a 95% confidence interval for the population mean might be

# %% [markdown]
# Q2: Python Function to Estimate Population Mean

# %%
def estimate_population_mean(sample_mean, sample_std, sample_size):
    import math
    standard_error = sample_std / math.sqrt(sample_size)
    return sample_mean, standard_error


sample_mean = 50
sample_std = 10
sample_size = 30

mean, std_error = estimate_population_mean(sample_mean, sample_std, sample_size)
print(f"Sample Mean: {mean}, Standard Error: {std_error}")
# Out:
# Sample Mean: 50, Standard Error: 1.8257418583505538

# %% [markdown]
# ## Q3: What is Hypothesis Testing? Why is it Used? Importance of Hypothesis Testing.
#
# Hypothesis Testing is a statistical method used to make decisions or inferences about population parameters based on sample data. It involve
#
# Calculating Test Statistic: Based on sample data.
# Making a Decision: Comparing the test statistic to a critical value or using a p-value.
#
#
#
# Importance:
#
# It provides a structured framework for testing assumptions.
# It helps in making informed decisions.
# It is widely used in scientific research to validate findings.

# %% [markdown]
# ### Q4: Hypothesis about Average Weight of Male and Female College Students
#
# Null Hypothesis: The average weight of male college students is equal to the average weight of female college students.
#
# Alternative Hypothesis : The average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# ### Q5: Python Script for Hypothesis Test on Difference Between Two Population Means

# %%
import scipy.stats as stats

def two_sample_t_test(sample1, sample2):
    t_stat, p_value = stats.ttest_ind(sample1, sample2)
    return t_stat, p_value

# Example usage:
sample1 = [85, 90, 78, 92, 88]  # Sample data for population 1
sample2 = [75, 80, 72, 78, 74]  # Sample data for population 2

t_stat, p_value = two_sample_t_test(sample1, sample2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 3.8183766184073553, P-value: 0.005101484448796523

# %% [markdown]
# ### Q6: Null and Alternative Hypothesis Examples
# Null Hypothesis : There is no difference in the mean test scores of two different teaching methods.
# Alternative Hypothesis : There is a difference in the mean test scores of two different teaching methods.
#
#
# ### Q7: Steps in Hypothesis Testing
# Formulate Hypotheses: Define null  and alternative hypotheses.
# Choose Significance Level (α): Common choices are 0.05, 0.01.
# Collect Data: Obtain a random sample.
# Calculate Test Statistic: Depending on the test (e.g., t-test, z-test).
# Determine Critical Value or P-Value: Compare with 𝛼.
#
# Interpret Results: Draw conclusions based on the decision.
#
# ### Q8: P-Value and Its Significance
# P-Value: The probability of obtaining test results at least as extreme as the observed results, under the assumption that the null hypothesis is true.
#
# Significance:
#
# It helps in determining the strength of evidence against the null hypothesis.
#  .

# %%
# Q9: Generate a Student's T-Distribution Plot Using Python

import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

df = 10  # degrees of freedom
x = np.linspace(-4, 4, 1000)
y = stats.t.pdf(x, df)

plt.plot(x, y, label=f't-distribution (df={df})')
plt.title('Student\'s t-Distribution')
plt.xlabel('t')
plt.ylabel('Probability Density')
plt.legend()
plt.show()

# %% [markdown]
# ## Q10: Python Program for Two-Sample T-Test for Independent Samples

# %%
import numpy as np
import scipy.stats as stats

def two_sample_t_test(sample1, sample2):
    t_stat, p_value = stats.ttest_ind(sample1, sample2)
    return t_stat, p_value

# Example usage:
np.random.seed(0)
sample1 = np.random.normal(100, 10, 30)  # Sample 1
sample2 = np.random.normal(102, 10, 30)  # Sample 2

t_stat, p_value = two_sample_t_test(sample1, sample2)

print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 2.038305608359027, P-value: 0.04608766659289103

# %%
### Q11: Student’s T-Distribution and When to Use It
Student’s T-Distribution: A probability distribution used when the sample size is small and/or the population standard deviation is unknown. It is similar to the normal distribution but has heavier tails.

When to Use:

When dealing with small sample sizes (n < 30).
When the population standard deviation is unknown.
For hypothesis testing and confidence intervals involving means.
# Out:
#   Cell In[8], line 2
#     Student’s T-Distribution: A probability distribution used when the sample size is small and/or the population standard deviation is unknown. It is similar to the normal distribution but has heavier tails.
#            ^
# SyntaxError: invalid character '’' (U+2019)

# %% [markdown]
# ## Q12: What is t-statistic? State the formula for t-statistic.
# the t-statistic is the ratio of the difference in a number's estimated value from its assumed value to its standard error. It is used in hypothesis testing via Student's t-test. The t-statistic is used in a t-test to determine whether to support or reject the null hypothesis
